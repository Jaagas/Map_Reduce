# %% [markdown]
# ## BIG DATA Week 9 - MapReduce

# %% [markdown]
# ### Words and Lines Counter

# %%
# %%file my_py_file1.py
#firstly, create your py file

#example from MRJob and intro
from mrjob.job import MRJob
import re

class MapReducer1(MRJob):

    def mapper(self, _, line):
        words = line.lower().split(' ')
        for word in words:
            key = re.findall(r'[a-z0-9]+', word)
            for k in key:
                yield k,1

    def reducer(self, key, values):
        yield key, sum(values)  #define keys and values


if __name__ == '__main__':
    MapReducer1.run()
# Out:
# Overwriting my_py_file1.py

# %% [markdown]
# #### For output:

# %%
# !python my_py_file1.py "C:\Users\Hp Probook\Documents\map_reduce\inpt data/*.txt" > my_output_file1.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file1.Hp Probook.20230102.171244.156083
# Running step 1 of 1...
# job output is in C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file1.Hp Probook.20230102.171244.156083\output
# Streaming final output from C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file1.Hp Probook.20230102.171244.156083\output...
# Removing temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file1.Hp Probook.20230102.171244.156083...

# %% [markdown]
# ### voter Count with Combiner

# %%
# %%file my_py_file2.py
#firstly, create your py file

#file word count. lots of intentional mistakes
from mrjob.job import MRJob


class MapREducer(MRJob):
    def mapper(self, _, line):
        location, time, voter = line.split(",")
        voter = int(voter)
        yield location, voter

    def reducer(self, location, voters):
        min_voter = next(voters)
        max_voter = min_voter
        for item in voters:
            min_voter = min(item, min_voter)
            max_voter = max(item, max_voter)
        yield location, (min_voter, max_voter)


if __name__ == '__main__':
    MapREducer.run()
# Out:
# Writing my_py_file2.py

# %% [markdown]
# #### For output:

# %%
# !python my_py_file2.py "C:\Users\Hp Probook\Documents\map_reduce\input2" > my_output_file2.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file2.Hp Probook.20230102.173452.879709
# Running step 1 of 1...
# job output is in C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file2.Hp Probook.20230102.173452.879709\output
# Streaming final output from C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file2.Hp Probook.20230102.173452.879709\output...
# Removing temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file2.Hp Probook.20230102.173452.879709...
