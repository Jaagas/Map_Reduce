# %% [markdown]
# ## BIG DATA Week 9 - MapReduce

# %%
# %%file my_py_file3.py
#firstly, create your py file

#example from MRJob and intro
from mrjob.job import MRJob

class Map_Reducer1(MRJob):

    def mapper(self, _, line):
        key = line.split(",")[1].split("\t")[0] 
        value = float(line.split("\t")[1])
        if value>=37.0:
            yield key,1

    def reducer(self, key, values):
        yield key, sum(values)  #define keys and values


if __name__ == '__main__':
    Map_Reducer1.run()
# Out:
# Overwriting my_py_file3.py

# %% [markdown]
# #### For output:

# %%
# !python my_py_file3.py "C:\Users\Hp Probook\Documents\map_reduce\input3" > my_output_file3.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file3.Hp Probook.20230102.181953.328564
# Running step 1 of 1...
# job output is in C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file3.Hp Probook.20230102.181953.328564\output
# Streaming final output from C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file3.Hp Probook.20230102.181953.328564\output...
# Removing temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file3.Hp Probook.20230102.181953.328564...

# %% [markdown]
# ### Count with Combiner

# %%
# %%file my_py_file4.py
#firstly, create your py file

#file word count. lots of intentional mistakes
from mrjob.job import MRJob


class Map_REducer(MRJob):
    def mapper(self, _, line):
        key = line.split(",")[1]
        yield key, 1

    def reducer(self, key, values):
        yield key, sum(values)


if __name__ == '__main__':
    Map_REducer.run()
# Out:
# Writing my_py_file4.py

# %% [markdown]
# #### For output:

# %%
# !python my_py_file4.py "C:\Users\Hp Probook\Documents\map_reduce\input4" > my_output_file4.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file4.Hp Probook.20230102.182725.353948
# Running step 1 of 1...
# job output is in C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file4.Hp Probook.20230102.182725.353948\output
# Streaming final output from C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file4.Hp Probook.20230102.182725.353948\output...
# Removing temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file4.Hp Probook.20230102.182725.353948...

# %%
# %%file my_py_file5.py
#firstly, create your py file

#example from MRJob and intro
from mrjob.job import MRJob
import re

class Map__Reducer(MRJob):

    def mapper(self, _, line):
        words = line.lower().split(' ')
        for word in words:
            key = re.findall(r'[a-z0-9]+', word)
            for k in key:
                yield k,1

    def reducer(self, key, values):
        yield key, sum(values)  #define keys and values


if __name__ == '__main__':
    Map__Reducer.run()
# Out:
# Writing my_py_file5.py

# %%
# !python my_py_file5.py "C:\Users\Hp Probook\Documents\map_reduce\input5" > my_output_file5.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file5.Hp Probook.20230102.183355.571126
# Running step 1 of 1...
# job output is in C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file5.Hp Probook.20230102.183355.571126\output
# Streaming final output from C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file5.Hp Probook.20230102.183355.571126\output...
# Removing temp directory C:\Users\HPPROB~1\AppData\Local\Temp\my_py_file5.Hp Probook.20230102.183355.571126...
